# %%
import pandas as pd
# import pandasql as ps
import matplotlib.pyplot as plt
# Import argsort
from numpy import argsort
from Functions.connection.connection import *
from Functions.AlertP1.data_cleaning import *
from Functions.AlertP1.features import *
from Functions.analysis.step_analysis import *
from Functions.AlertP1.dummy_features import *
from Functions.Models.Logistic_regression import *
from Functions.Models.evaluation import *

# %% [markdown]
# ## Connection to databse

# %%
alertP1=connection("/Users/MarouanKamoun/Desktop/HGO pbl/credentials.csv")
# Out:
# Tables: [('ConsultaUrgencia_doentespedidosconsultaNeurologia2012',), ('consultaneurologia2012',), ('consultaneurologia201216anon_true',), ('hgo_data_032023',)]
# 643

# %% [markdown]
# ## Data cleaning

# %%
#changing columns with date to a datetime
date_format_alertP1(alertP1)
#change the blank values in proveniencia and priority to unknown
replace_blank(alertP1)
#merge duplicated entity
entity_duplicated(alertP1)
#create a column with the output of a referral and select the refused and accepted ones
alertP1=result(alertP1)
# Out:
# c:\Users\MarouanKamoun\Desktop\HGO pbl\PBL-HGO\PBL-HGO\Functions\AlertP1\data_cleaning.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alertP1['PROVENIENCIA'][alertP1['PROVENIENCIA']=='']='unknown'
# c:\Users\MarouanKamoun\Desktop\HGO pbl\PBL-HGO\PBL-HGO\Functions\AlertP1\data_cleaning.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alertP1['CTH_PRIOR'][alertP1['CTH_PRIOR']=='']='unknown'
# c:\Users\MarouanKamoun\Desktop\HGO pbl\PBL-HGO\PBL-HGO\Functions\AlertP1\data_cleaning.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alertP1['COD_UNID_SAUDE_PROV'][alertP1['COD_UNID_SAUDE_PROV']==3151401]=3151400
# c:\Users\MarouanKamoun\Desktop\HGO pbl\PBL-HGO\PBL-HGO\Functions\AlertP1\data_cleaning.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alertP1['COD_UNID_SAUDE_PROV'][alertP1['COD_UNID_SAUDE_PROV']==3150503]=3150572
# c:\Users\MarouanKamoun\Desktop\HGO pbl\PBL-HGO\PBL-HGO\Functions\AlertP1\data_cleaning.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alertP1['COD_UNID_SAUDE_PROV'][alertP1['COD_UNID_SAUDE_PROV']==3151603]=3151671
# c:\Users\MarouanKamoun\Desktop\HGO pbl\PBL-HGO\PBL-HGO\Functions\AlertP1\data_cleaning.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alertP1['COD_UNID_SAUDE_PROV'][alertP1['COD_UNID_SAUDE_PROV']==3152101]=3152100
# c:\Users\MarouanKamoun\Desktop\HGO pbl\PBL-HGO\PBL-HGO\Functions\AlertP1\data_cleaning.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alertP1['PROVENIENCIA'][alertP1['COD_UNID_SAUDE_PROV']==3150371]='CTH'

# %% [markdown]
# ## Creating new columns for features

# %%
bef_accepted(alertP1)
class_area(alertP1)
text_length(alertP1)
referral_steps(alertP1)
speciality(alertP1)
alertP1=unit(alertP1)
alertP1=alertP1.sort_values('DATA_RECEPCAO')
alertP1
# Out:
# c:\Users\MarouanKamoun\Desktop\HGO pbl\PBL-HGO\PBL-HGO\Functions\AlertP1\features.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alertP1['step'][alertP1['step']>=3]='3+'
# c:\Users\MarouanKamoun\Desktop\HGO pbl\PBL-HGO\PBL-HGO\Functions\AlertP1\features.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alertP1['unit'][(alertP1['COD_UNID_SAUDE_PROV']==3151772) & (alertP1['DATA_RECEPCAO']<'23/07/2012')]='CS'
# c:\Users\MarouanKamoun\Desktop\HGO pbl\PBL-HGO\PBL-HGO\Functions\AlertP1\features.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alertP1['unit'][(alertP1['COD_UNID_SAUDE_PROV']==3151201) & (alertP1['DATA_RECEPCAO']<'01/04/2015')]='CS'
# c:\Users\MarouanKamoun\Desktop\HGO pbl\PBL-HGO\PBL-HGO\Functions\AlertP1\features.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alertP1['unit'][(alertP1['COD_UNID_SAUDE_PROV']==3150501) & (alertP1['DATA_RECEPCAO']<'15/05/2015')]='CS'
# c:\Users\MarouanKamoun\Desktop\HGO pbl\PBL-HGO\PBL-HGO\Functions\AlertP1\features.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alertP1['unit'][(alertP1['COD_UNID_SAUDE_PROV']==3150573) & (alertP1['DATA_RECEPCAO']<'15/05/2015')]='CS'
#      ID_DOENTE  PROCESSO COD_REFERENCIA    COD_PZ  COD_UNID_SAUDE_PROV  \
# 9915    SEAFHB  BBLVVLDC       LOHHHLOV   SFGHADG              3150305
# 6944    ZDGGGA  BMJNMVVJ       LOHHHHRS                              0
# 6542    ZZZBGG  BMJIBILB       LOHHHOHO   SSBSEGA              3150301
# 3067    DSHCGG   BMIBJIE       LOHHHOUQ   SFAAECF              3151672
# 2078    AESBSC   NINBJJC       LOHHHPTO                              0
# ...        ...       ...            ...       ...                  ...
# 7353    ZSGCCF  BMJCJLIJ       LSHVLHUO  ZEFHCECF              3150672
# 4044    CDABCC  VLNVILNB       LSHVLLUO  ZEFZDDBB              3150371
# 6424     FCDEF  BIJIMMIJ       LSHVLOQU                              0
# 9425    EBESGE  BDVDJJIB       LSHVLLVV                              0
# 5513    GFHDGC  VENBCMMN       LTHHHOTL  ZEFZEDDG              3150371
#
#                            UNID_PROV TIPO_UNID PROVENIENCIA COD_CTH_PRIOR  \
# 9915           UCSP RAINHA D. LEONOR    CS/USF          CTH
# 6944                                     OUTRA      unknown
# 6542             FRANCISCO X NORONHA    CS/USF          CTH
# 3067              USF AMORA SAUDAVEL    CS/USF          CTH
# 2078                                     OUTRA      unknown
# ...                              ...       ...          ...           ...
# 7353    USF FEIJO-CS COVA DA PIEDADE    CS/USF          CTH             3
# 4044  USF S JOAO DO PRAGAL-CS ALMADA    CS/USF          CTH             3
# 6424                                     OUTRA          SAM             3
# 9425                                     OUTRA          SAM
# 5513  USF S JOAO DO PRAGAL-CS ALMADA    CS/USF          CTH             3
#
#      CTH_PRIOR  ...  resume saída mês_saida  ano_saida Texto result  \
# 9915   unknown  ...    30/03/2012         3       2012            1
# 6944   unknown  ...    01/08/2012         8       2012            1
# 6542   unknown  ...    10/01/2012         1       2012            0
# 3067   unknown  ...    12/03/2012         3       2012            1
# 2078   unknown  ...    22/01/2013         1       2013            1
# ...        ...  ...           ...       ...        ...   ...    ...
# 7353    Normal  ...    20/03/2017         3       2017            1
# 4044    Normal  ...    21/03/2017         3       2017            1
# 6424    Normal  ...    01/03/2018         3       2018            1
# 9425   unknown  ...    04/09/2017         9       2017            1
# 5513    Normal  ...    09/02/2017         2       2017            1
#
#               area text_length step     speciality_type   unit
# 9915   inside area           0    1  Other specialities   UCSP
# 6944  outside area           0    1   General Neurology    HGO
# 6542  outside area           0    1   General Neurology  outro
# 3067   inside area           0    1  Other specialities    USF
# 2078  outside area           0    1   General Neurology    HGO
# ...            ...         ...  ...                 ...    ...
# 7353   inside area           0    2   General Neurology    USF
# 4044   inside area           0    1   General Neurology    USF
# 6424  outside area           0    2  Other specialities    HGO
# 9425  outside area           0    1  Other specialities    HGO
# 5513   inside area           0    1   General Neurology    USF
#
# [9374 rows x 37 columns]

# %% [markdown]
# ## structured data with dummies

# %%
data=structured_data_dummies(alertP1)
print(data.columns)
data
# Out:
# Index([          'ID_DOENTE',            'PROCESSO',      'COD_REFERENCIA',
#                     'COD_PZ', 'COD_UNID_SAUDE_PROV',           'UNID_PROV',
#                  'TIPO_UNID',       'COD_CTH_PRIOR',           'CTH_PRIOR',
#          'COD_MOTIVO_RECUSA',   'DES_MOTIVO_RECUSA',   'COD_ESPECIALIDADE',
#          'DES_ESPECIALIDADE',          'agrupadora',      'OUTRA_ENTIDADE',
#              'DATA_RECEPCAO',          'DATA_ENVIO',        'DATA_RETORNO',
#                   'NUM_TAXA',              'ESTADO',       'DATA_MARCACAO',
#            'DATA_REALIZACAO',         'OBSERVACOES',         'Mês_entrada',
#                'Ano_entrada',   'trata data recusa',        'resume saída',
#                  'mês_saida',           'ano_saida',               'Texto',
#                     'result',         'text_length',        'outside area',
#                        'SAM',                 'SON',             'unknown',
#         'Other specialities',                     2,                  '3+',
#                       'HOSP',                'UCSP',                 'USF'],
#       dtype='object')
#      ID_DOENTE  PROCESSO COD_REFERENCIA    COD_PZ  COD_UNID_SAUDE_PROV  \
# 9915    SEAFHB  BBLVVLDC       LOHHHLOV   SFGHADG              3150305
# 6944    ZDGGGA  BMJNMVVJ       LOHHHHRS                              0
# 6542    ZZZBGG  BMJIBILB       LOHHHOHO   SSBSEGA              3150301
# 3067    DSHCGG   BMIBJIE       LOHHHOUQ   SFAAECF              3151672
# 2078    AESBSC   NINBJJC       LOHHHPTO                              0
# ...        ...       ...            ...       ...                  ...
# 7353    ZSGCCF  BMJCJLIJ       LSHVLHUO  ZEFHCECF              3150672
# 4044    CDABCC  VLNVILNB       LSHVLLUO  ZEFZDDBB              3150371
# 6424     FCDEF  BIJIMMIJ       LSHVLOQU                              0
# 9425    EBESGE  BDVDJJIB       LSHVLLVV                              0
# 5513    GFHDGC  VENBCMMN       LTHHHOTL  ZEFZEDDG              3150371
#
#                            UNID_PROV TIPO_UNID COD_CTH_PRIOR CTH_PRIOR  \
# 9915           UCSP RAINHA D. LEONOR    CS/USF                 unknown
# 6944                                     OUTRA                 unknown
# 6542             FRANCISCO X NORONHA    CS/USF                 unknown
# 3067              USF AMORA SAUDAVEL    CS/USF                 unknown
# 2078                                     OUTRA                 unknown
# ...                              ...       ...           ...       ...
# 7353    USF FEIJO-CS COVA DA PIEDADE    CS/USF             3    Normal
# 4044  USF S JOAO DO PRAGAL-CS ALMADA    CS/USF             3    Normal
# 6424                                     OUTRA             3    Normal
# 9425                                     OUTRA                 unknown
# 5513  USF S JOAO DO PRAGAL-CS ALMADA    CS/USF             3    Normal
#
#       COD_MOTIVO_RECUSA  ... outside area  SAM SON unknown  \
# 9915                  0  ...            0    0   0       0
# 6944                  0  ...            1    0   0       1
# 6542                  7  ...            1    0   0       0
# 3067                  0  ...            0    0   0       0
# 2078                  0  ...            1    0   0       1
# ...                 ...  ...          ...  ...  ..     ...
# 7353                  0  ...            0    0   0       0
# 4044                  0  ...            0    0   0       0
# 6424                  0  ...            1    1   0       0
# 9425                  0  ...            1    1   0       0
# 5513                  0  ...            0    0   0       0
#
#       Other specialities  2 3+ HOSP  UCSP USF
# 9915                   1  0  0    0     1   0
# 6944                   0  0  0    1     0   0
# 6542                   0  0  0    0     0   0
# 3067                   1  0  0    0     0   1
# 2078                   0  0  0    1     0   0
# ...                  ... .. ..  ...   ...  ..
# 7353                   0  1  0    0     0   0
# 4044                   0  0  0    0     0   1
# 6424                   1  1  0    1     0   0
# 9425                   1  0  0    1     0   0
# 5513                   0  0  0    0     0   1
#
# [9374 rows x 42 columns]

# %% [markdown]
# ## Logistic regression for all dataset

# %% [markdown]
# features and coefficients

# %%
#split dataset in features and target variable// Question: is it the right option?
eliminate_cols=['text_length','ID_DOENTE','PROCESSO','COD_REFERENCIA','result','COD_PZ','COD_UNID_SAUDE_PROV','UNID_PROV','TIPO_UNID','COD_CTH_PRIOR','CTH_PRIOR','COD_MOTIVO_RECUSA','DES_MOTIVO_RECUSA','COD_ESPECIALIDADE','DES_ESPECIALIDADE','agrupadora','OUTRA_ENTIDADE','DATA_RECEPCAO','DATA_ENVIO','DATA_RETORNO','NUM_TAXA','ESTADO','DATA_MARCACAO','DATA_REALIZACAO','OBSERVACOES','Mês_entrada','Ano_entrada','trata data recusa','resume saída','mês_saida','ano_saida','Texto']
X = data.drop(eliminate_cols,axis=1)# Features
y = data.result # Target variable
features=X.columns
#log_regression is defined in functions
y_pred,coefficients,intercept,X_train, X_test, y_train, y_test=log_regression(X,y)
df = pd.DataFrame(features, columns =['Feature'])
df['coefficients']=coefficients.T
df.sort_values(by= 'coefficients',ascending=False)
# Out:
#               Feature  coefficients
# 0        outside area     -0.498910
# 1                 SAM     -0.058484
# 2                 SON     -1.884672
# 3             unknown     -1.041765
# 4  Other specialities      3.563379
# 5                   2      0.241350
# 6                  3+     -0.215898
# 7                HOSP     -0.357963
# 8                UCSP     -0.105971
# 9                 USF      0.493537

# %%
y_df = pd.DataFrame(y_test)
distribution = y_df["result"].value_counts()
distribution
# Out:
# 1    1317
# 0     558
# Name: result, dtype: int64

# %% [markdown]
# metrics

# %%
# Evaluate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Evaluate the recall of the model
recall = recall_score(y_test, y_pred)
print("Recall:", recall)

# Evaluate the precision of the model
precision = precision_score(y_test, y_pred)
print("Precision:", precision)

# Calculate the confusion matrix of the model
cnf_matrix = confusion_matrix(y_test, y_pred)


class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Print the evaluation matrix
target_names = ['refused', 'accepted']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
# Accuracy: 0.7136
# Recall: 0.5306945567067546
# Precision: 0.6862121912561088
#               precision    recall  f1-score   support
#
#      refused       0.66      0.08      0.14       558
#     accepted       0.72      0.98      0.83      1317
#
#     accuracy                           0.71      1875
#    macro avg       0.69      0.53      0.48      1875
# weighted avg       0.70      0.71      0.62      1875

# %% [markdown]
# p value

# %%
p_value(X,y)
# Out:
#               Feature       p_value
# 0        outside area  0.000000e+00
# 1                 SAM  2.518123e-14
# 2                 SON  0.000000e+00
# 3             unknown  0.000000e+00
# 4  Other specialities  0.000000e+00
# 5                   2  2.934509e-08
# 6                  3+  1.456288e-01
# 7                HOSP  0.000000e+00
# 8                UCSP  1.476414e-02
# 9                 USF  0.000000e+00

# %% [markdown]
# ## Logistic regression text variables

# %%
#logistic regression text rows
data_no_text=data[data['text_length']>0]
#split dataset in features and target variable// Question: is it the right option?
eliminate_cols=['ID_DOENTE','PROCESSO','COD_REFERENCIA','result','COD_PZ','COD_UNID_SAUDE_PROV','UNID_PROV','TIPO_UNID','COD_CTH_PRIOR','CTH_PRIOR','COD_MOTIVO_RECUSA','DES_MOTIVO_RECUSA','COD_ESPECIALIDADE','DES_ESPECIALIDADE','agrupadora','OUTRA_ENTIDADE','DATA_RECEPCAO','DATA_ENVIO','DATA_RETORNO','NUM_TAXA','ESTADO','DATA_MARCACAO','DATA_REALIZACAO','OBSERVACOES','Mês_entrada','Ano_entrada','trata data recusa','resume saída','mês_saida','ano_saida','Texto']
X = data_no_text.drop(eliminate_cols,axis=1)# Features
y = data_no_text.result # Target variable
features=X.columns
#log_regression is defined in functions
y_pred,coefficients,intercept,X_train, X_test, y_train, y_test=log_regression(X,y)
df = pd.DataFrame(features, columns =['Feature'])
df['coefficients']=coefficients.T
df.sort_values(by= 'coefficients',ascending=False)
# Out:
# c:\Users\MarouanKamoun\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#                Feature  coefficients
# 0          text_length      0.001476
# 1         outside area      0.501333
# 2                  SAM      0.002981
# 3                  SON     -0.073211
# 4              unknown     -0.868712
# 5   Other specialities      3.264233
# 6                    2      0.185330
# 7                   3+      0.034588
# 8                 HOSP     -0.926181
# 9                 UCSP     -0.211410
# 10                 USF      0.361450

# %%
y_df = pd.DataFrame(y_test)
distribution = y_df["result"].value_counts()
distribution
# Out:
# 1    211
# 0    111
# Name: result, dtype: int64

# %% [markdown]
# metrics

# %%
# Evaluate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Evaluate the recall of the model
recall = recall_score(y_test, y_pred)
print("Recall:", recall)

# Evaluate the precision of the model
precision = precision_score(y_test, y_pred)
print("Precision:", precision)

# Calculate the confusion matrix of the model
cnf_matrix = confusion_matrix(y_test, y_pred)


class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Print the evaluation matrix
target_names = ['refused', 'accepted']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
# Accuracy: 0.7018633540372671
# Recall: 0.5825114213739806
# Precision: 0.7274332117217841
#               precision    recall  f1-score   support
#
#      refused       0.76      0.20      0.31       111
#     accepted       0.70      0.97      0.81       211
#
#     accuracy                           0.70       322
#    macro avg       0.73      0.58      0.56       322
# weighted avg       0.72      0.70      0.64       322

# %%
p_value(X,y)
# Out:
#                Feature       p_value
# 0          text_length  1.491237e-30
# 1         outside area  1.106719e-27
# 2                  SAM  1.051842e-04
# 3                  SON  7.611581e-04
# 4              unknown  2.499057e-31
# 5   Other specialities  4.704782e-23
# 6                    2  4.632841e-02
# 7                   3+  1.193271e-01
# 8                 HOSP  8.572967e-34
# 9                 UCSP  2.419156e-01
# 10                 USF  1.455616e-18

# %% [markdown]
# ## Logistic without high p-value

# %%
#logistic regression text rows
data_no_text=data[data['text_length']>0]
#split dataset in features and target variable// Question: is it the right option?
eliminate_cols=['ID_DOENTE','PROCESSO','COD_REFERENCIA','result','COD_PZ','COD_UNID_SAUDE_PROV','UNID_PROV','TIPO_UNID','COD_CTH_PRIOR','CTH_PRIOR','COD_MOTIVO_RECUSA','DES_MOTIVO_RECUSA','COD_ESPECIALIDADE','DES_ESPECIALIDADE','agrupadora','OUTRA_ENTIDADE','DATA_RECEPCAO','DATA_ENVIO','DATA_RETORNO','NUM_TAXA','ESTADO','DATA_MARCACAO','DATA_REALIZACAO','OBSERVACOES','Mês_entrada','Ano_entrada','trata data recusa','resume saída','mês_saida','ano_saida','Texto','UCSP','3+']
X = data_no_text.drop(eliminate_cols,axis=1)# Features
y = data_no_text.result # Target variable
features=X.columns
#log_regression is defined in functions
y_pred,coefficients,intercept,X_train, X_test, y_train, y_test=log_regression(X,y)
df = pd.DataFrame(features, columns =['Feature'])
df['coefficients']=coefficients.T
df.sort_values(by= 'coefficients',ascending=False)
# Out:
# c:\Users\MarouanKamoun\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               Feature  coefficients
# 0         text_length      0.001500
# 1        outside area      0.560235
# 2                 SAM      0.017471
# 3                 SON     -0.073378
# 4             unknown     -0.875359
# 5  Other specialities      3.237276
# 6                   2      0.161044
# 7                HOSP     -0.918158
# 8                 USF      0.404980

# %%
# Evaluate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Evaluate the recall of the model
recall = recall_score(y_test, y_pred)
print("Recall:", recall)
# Evaluate the precision of the model
precision = precision_score(y_test, y_pred)
print("Precision:", precision)

# Calculate the confusion matrix of the model
cnf_matrix = confusion_matrix(y_test, y_pred)


class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Print the evaluation matrix
target_names = ['refused', 'accepted']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
# Accuracy: 0.7049689440993789
# Recall: 0.5848810896204262
# Precision: 0.7414965986394557
#               precision    recall  f1-score   support
#
#      refused       0.79      0.20      0.32       111
#     accepted       0.70      0.97      0.81       211
#
#     accuracy                           0.70       322
#    macro avg       0.74      0.58      0.56       322
# weighted avg       0.73      0.70      0.64       322

# %%
p_value(X,y)
# Out:
#               Feature       p_value
# 0         text_length  1.491237e-30
# 1        outside area  1.106719e-27
# 2                 SAM  1.051842e-04
# 3                 SON  7.611581e-04
# 4             unknown  2.499057e-31
# 5  Other specialities  4.704782e-23
# 6                   2  4.632841e-02
# 7                HOSP  8.572967e-34
# 8                 USF  1.455616e-18

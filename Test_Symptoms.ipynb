# %%
import pandas as pd 
from Functions.NLP.alertp1_nlp import *
from Functions.connection.connection import *
from Functions.AlertP1.data_cleaning import *

data = pd.read_csv("downloads/modified_dataset_vanilla.csv")

#changing columns with date to a datetime
date_format_alertP1(data)
#change the blank values in proveniencia and priority to unknown
replace_blank(data)
#create a column with the output of a referral and select the refused and accepted ones
data=result(data)
data=data.sort_values('DATA_RETORNO')
data = data.dropna(subset=['Texto'])
data = data.drop('clean_text', axis=1)

# compute the number of rows to select
n = int(len(data) * 0.8)

# select the first 80% of rows using slicing
train = data.iloc[:n]
#select the last 20%
test = data.iloc[n:]
#n+1 so I don't have an overlapp in the distribution

train["80"] = train["Texto"]

random_rows = train.sample(20)

categorize_symptoms_simple(random_rows,"80","Data/symptoms_data_big.xlsx", 80)
add_textcount_columns(random_rows,"80","symptom_identified")
random_rows.head()
# Out:
# /Users/miguelcosta/Desktop/PBL/PBL-HGO-1/Functions/AlertP1/data_cleaning.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alertP1['PROVENIENCIA'][alertP1['PROVENIENCIA']=='']='unknown'
# /Users/miguelcosta/Desktop/PBL/PBL-HGO-1/Functions/AlertP1/data_cleaning.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alertP1['CTH_PRIOR'][alertP1['CTH_PRIOR']=='']='unknown'
# /var/folders/g5/fkg03q9j52z1zkf7tm78r7pr0000gn/T/ipykernel_61178/3147224754.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["80"] = train["Texto"]
# /Users/miguelcosta/Desktop/PBL/PBL-HGO-1/Functions/NLP/alertp1_nlp.py:193: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for i, text in df[column].iteritems():
#      ID_DOENTE PROCESSO COD_REFERENCIA    COD_PZ  COD_UNID_SAUDE_PROV  \
# 784     FZFAZC  VLEIDBM       LQHLLLTU       NaN                    0
# 380     ZCFEEE   LICBBB       LOHPHPSR       NaN                    0
# 405     SCSDZB   LIBEBB       LRHQUQLL  ZHFDACBZ              3151576
# 1356    SDCEHC  IIJEICC       LOHHUQTH   SGECGBE              3150502
# 415     SCGAAG   LMJINB       LQHORPVH       NaN                    0
#
#                  UNID_PROV TIPO_UNID PROVENIENCIA  COD_CTH_PRIOR CTH_PRIOR  \
# 784                    NaN     OUTRA          SAM            NaN   unknown
# 380                    NaN     OUTRA      unknown            NaN   unknown
# 405   USF PINHAL DE FRADES    CS/USF          CTH            3.0    Normal
# 1356  CHARNECA DA CAPARICA    CS/USF          CTH            NaN   unknown
# 415                    NaN     OUTRA          SAM            NaN   unknown
#
#       ...  Mês_entrada Ano_entrada  trata data recusa resume saída mês_saida  \
# 784   ...            2        2014         2014-03-31   31/03/2014         3
# 380   ...            7        2012         2012-07-06   06/07/2012         7
# 405   ...            8        2015         2015-08-05   24/11/2015        11
# 1356  ...            2        2012         2012-03-02   13/04/2012         4
# 415   ...            5        2014         2015-01-26   26/01/2015         1
#
#       ano_saida                                              Texto result  \
# 784        2014  instabilidade crónica.  Perda de sensibilidade...      0
# 380        2012                             Sem relatorio clinico       0
# 405        2015  64 anos, apresenta quadro de alterações da mem...      1
# 1356       2012  gravida de 15 semanas. enxaqueca persistente s...      1
# 415        2015  48 anos . Neoplasia da mama desde 2001 . Actua...      1
#
#                                                      80  symptom_identified
# 784   instabilidade crónica.  Perda de sensibilidade...                   1
# 380                              Sem relatorio clinico                    0
# 405   64 anos, apresenta quadro de symptom_identifie...                   4
# 1356  gravida de 15 semanas. symptom_identified pers...                   1
# 415   48 anos . symptom_identified da mama desde 200...                   2
#
# [5 rows x 34 columns]

# %%
random_rows["symptom_identified"].sum()
# Out:
# 36

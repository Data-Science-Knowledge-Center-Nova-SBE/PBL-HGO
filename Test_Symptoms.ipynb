# %%
import pandas as pd 
from Functions.NLP.alertp1_nlp import *
from Functions.connection.connection import *
from Functions.AlertP1.data_cleaning import *

data = pd.read_csv("downloads/modified_dataset_vanilla.csv")

#changing columns with date to a datetime
date_format_alertP1(data)
#change the blank values in proveniencia and priority to unknown
replace_blank(data)
#create a column with the output of a referral and select the refused and accepted ones
data=result(data)
data=data.sort_values('DATA_RETORNO')
data = data.dropna(subset=['Texto'])
data = data.drop('clean_text', axis=1)

# compute the number of rows to select
n = int(len(data) * 0.8)

# select the first 80% of rows using slicing
train = data.iloc[:n]
#select the last 20%
test = data.iloc[n:]
#n+1 so I don't have an overlapp in the distribution

lower_text(train,"Texto","80")

random_rows = train.sample(20, random_state= 20)

categorize_symptoms_simple(random_rows,"80","Data/symptoms_data_big.xlsx", 80)
add_textcount_columns(random_rows,"80","symptom_identified")
random_rows.head()
# Out:
# /Users/miguelcosta/Desktop/PBL/PBL-HGO-1/Functions/AlertP1/data_cleaning.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alertP1['PROVENIENCIA'][alertP1['PROVENIENCIA']=='']='unknown'
# /Users/miguelcosta/Desktop/PBL/PBL-HGO-1/Functions/AlertP1/data_cleaning.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alertP1['CTH_PRIOR'][alertP1['CTH_PRIOR']=='']='unknown'
# /Users/miguelcosta/Desktop/PBL/PBL-HGO-1/Functions/NLP/alertp1_nlp.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_column] = df[column].str.lower()
# /Users/miguelcosta/Desktop/PBL/PBL-HGO-1/Functions/NLP/alertp1_nlp.py:193: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for i, text in df[column].iteritems():
#      ID_DOENTE   PROCESSO COD_REFERENCIA    COD_PZ  COD_UNID_SAUDE_PROV  \
# 1175    FAZDZA    ILBIBJD       LSHLLTVO  ZZBHEAFH              3150502
# 26      DZHBDC     LVEDIM       LRHRLLSR  ZHFBEFHS              3150305
# 1441    FAEEHZ  IIVJMJJJJ       LQHLHOOO   BHADAGH              3151575
# 528     DGDGEZ    VLMDJEI       LPHRTVVQ   CCEFBEF              3150371
# 910     EBAGCC    LLCICNB       LQHSRQQP   GEESEZA              3151574
#
#                            UNID_PROV TIPO_UNID PROVENIENCIA  COD_CTH_PRIOR  \
# 1175            CHARNECA DA CAPARICA    CS/USF          CTH            3.0
# 26             UCSP RAINHA D. LEONOR    CS/USF          CTH            NaN
# 1441            USF TORRE DA MARINHA    CS/USF          CTH            NaN
# 528   USF S JOAO DO PRAGAL-CS ALMADA    CS/USF          CTH            NaN
# 910                   USF CSI SEIXAL    CS/USF          CTH            3.0
#
#      CTH_PRIOR  ...  Mês_entrada Ano_entrada  trata data recusa resume saída  \
# 1175    Normal  ...            2        2016         2016-02-24   31/03/2016
# 26     unknown  ...            8        2015         2015-08-18   18/08/2015
# 1441   unknown  ...            2        2014         2014-04-04   15/05/2014
# 528    unknown  ...           11        2013         2013-12-13   10/01/2014
# 910     Normal  ...           11        2014         2015-05-28   28/05/2015
#
#      mês_saida  ano_saida                                              Texto  \
# 1175         3       2016  TRÉMULO MAIS DOS MEMBROS SUPERIORES - PARKINSO...
# 26           8       2015  Doente com 75 anos que sofreu avc isquemico em...
# 1441         5       2014  Justificação Parquinsonismo Sindrome demencial...
# 528          1       2014  homem de 51 anos com alterações neurológicas q...
# 910          5       2015  Utente de 32 anos, sem antec. clinicos relevan...
#
#      result                                                 80  \
# 1175      1  trémulo mais dos membros superiores - symptom_...
# 26        0  doente com 75 anos que sofreu symptom_identifi...
# 1441      1  justificação symptom_identified sindrome sympt...
# 528       1  homem de 51 anos com symptom_identified neurol...
# 910       1  utente de 32 anos, sem antec. clinicos relevan...
#
#       symptom_identified
# 1175                   4
# 26                     1
# 1441                  11
# 528                    5
# 910                    6
#
# [5 rows x 34 columns]

# %%
load_data("random_rows_symp.csv",random_rows)
# Out:
# Data file 'random_rows_symp.csv' downloaded and saved to 'downloads' directory.
#      ID_DOENTE   PROCESSO COD_REFERENCIA    COD_PZ  COD_UNID_SAUDE_PROV  \
# 1175    FAZDZA    ILBIBJD       LSHLLTVO  ZZBHEAFH              3150502
# 26      DZHBDC     LVEDIM       LRHRLLSR  ZHFBEFHS              3150305
# 1441    FAEEHZ  IIVJMJJJJ       LQHLHOOO   BHADAGH              3151575
# 528     DGDGEZ    VLMDJEI       LPHRTVVQ   CCEFBEF              3150371
# 910     EBAGCC    LLCICNB       LQHSRQQP   GEESEZA              3151574
# 344     SFZGAE     LINIMN       LOHPTQHO       NaN                    0
# 372     DSFFGE     LICVID       LQHSVOSU   GSHSGAB              3150506
# 954     FEEZGB    LLCCVIM       LQHHROVH       NaN                    0
# 1605    ZDEGDC    MILLVCE       LQHSVLUR       NaN                    0
# 1137    FFEFSH    ILBJDLB       LPHQVLLV       NaN                    0
# 234     DSGAFZ     LLDDEN       LRHQUUHO  ZHFDFDAC              3150571
# 72      SSCGZZ     LVBCJC       LRHQPOHL  ZHSDZABG              3152471
# 607     ZCAZGF    VLNIMEB       LRHSRLTT       NaN                    0
# 313     ZHFFBF     LIINBV       LRHOQTRH       NaN                    0
# 510     ZCEAFB    VLMCJJJ       LRHQRSRT  ZHSCFCHZ              3150571
# 174     SFCEHD     LLNCCL       LQHLVUSU   BEZACZC              3152401
# 83      ZHGBSG     LLJVLN       LQHQOPVV   BBEGZZF              3150572
# 1613    FDFASG    MILLNIB       LPHOSLLT   AGCEBAZ              3150572
# 1119    DFBFHE    LLDBEMN       LQHHOTSO   CGDZBAA              3151571
# 856     FHZFAZ    LLEBCLL       LOHORRUP   FEFZEFS              3151771
#
#                            UNID_PROV TIPO_UNID PROVENIENCIA  COD_CTH_PRIOR  \
# 1175            CHARNECA DA CAPARICA    CS/USF          CTH            3.0
# 26             UCSP RAINHA D. LEONOR    CS/USF          CTH            NaN
# 1441            USF TORRE DA MARINHA    CS/USF          CTH            NaN
# 528   USF S JOAO DO PRAGAL-CS ALMADA    CS/USF          CTH            NaN
# 910                   USF CSI SEIXAL    CS/USF          CTH            3.0
# 344                              NaN     OUTRA      unknown            NaN
# 372            UCSP COSTA E TRAFARIA    CS/USF          CTH            NaN
# 954                              NaN     OUTRA          SAM            NaN
# 1605                             NaN     OUTRA          SAM            NaN
# 1137                             NaN     OUTRA      unknown            NaN
# 234    USF SOBREDA-CS COSTA CAPARICA    CS/USF          CTH            3.0
# 72               USF SERVIR SAUDE-CS    CS/USF          CTH            3.0
# 607                              NaN     OUTRA          SAM            NaN
# 313                              NaN     OUTRA          SAM            NaN
# 510    USF SOBREDA-CS COSTA CAPARICA    CS/USF          CTH            3.0
# 174                    UCSP CORROIOS    CS/USF          CTH            NaN
# 83             USF MONTE DA CAPARICA    CS/USF          CTH            NaN
# 1613           USF MONTE DA CAPARICA    CS/USF          CTH            NaN
# 1119            USF FFMAIS-CS SEIXAL    CS/USF          CTH            NaN
# 856       USF DO CASTELO-CS SESIMBRA    CS/USF          CTH            NaN
#
#      CTH_PRIOR  ...  Mês_entrada Ano_entrada  trata data recusa resume saída  \
# 1175    Normal  ...            2        2016         2016-02-24   31/03/2016
# 26     unknown  ...            8        2015         2015-08-18   18/08/2015
# 1441   unknown  ...            2        2014         2014-04-04   15/05/2014
# 528    unknown  ...           11        2013         2013-12-13   10/01/2014
# 910     Normal  ...           11        2014         2015-05-28   28/05/2015
# 344    unknown  ...            8        2012         2012-08-29   29/08/2012
# 372    unknown  ...           12        2014         2015-06-11   11/06/2015
# 954    unknown  ...            1        2014         2014-03-31   22/05/2014
# 1605   unknown  ...           12        2014         2015-03-30   13/04/2015
# 1137   unknown  ...           10        2013         2013-10-17   27/06/2014
# 234     Normal  ...            8        2015         2015-08-06   26/11/2015
# 72      Normal  ...            7        2015         2015-07-13   21/09/2015
# 607    unknown  ...           10        2015         2015-10-22   22/10/2015
# 313    unknown  ...            4        2015         2015-07-23   23/07/2015
# 510     Normal  ...            7        2015         2015-07-23   16/11/2015
# 174    unknown  ...            4        2014         2014-06-25   26/08/2014
# 83     unknown  ...            8        2014         2015-04-13   13/04/2015
# 1613   unknown  ...            6        2013         2013-06-07   07/06/2013
# 1119   unknown  ...            1        2014         2014-03-07   20/03/2014
# 856    unknown  ...            6        2012         2012-06-25   21/08/2012
#
#      mês_saida  ano_saida                                              Texto  \
# 1175         3       2016  TRÉMULO MAIS DOS MEMBROS SUPERIORES - PARKINSO...
# 26           8       2015  Doente com 75 anos que sofreu avc isquemico em...
# 1441         5       2014  Justificação Parquinsonismo Sindrome demencial...
# 528          1       2014  homem de 51 anos com alterações neurológicas q...
# 910          5       2015  Utente de 32 anos, sem antec. clinicos relevan...
# 344          8       2012                                      Parkinsonismo
# 372          6       2015  Doente do sexo masculino com 82 anos, analfabe...
# 954          5       2014  Homem de 76 anos avaliado em consulta por coli...
# 1605         4       2015  Doente de 79 anos, com quadro com pelo menos 1...
# 1137         6       2014                                     sem informação
# 234         11       2015  Cefaleia (excluindo N02 N89 R09) (N01) Sintoma...
# 72           9       2015  Reencaminho a utente porque o pedido realizado...
# 607         10       2015  Homem 88 anos, autonomo nas AVD residente com ...
# 313          7       2015  Doente 22 anos, seguida na consulta externa of...
# 510         11       2015  Vida basal relativamente ativa para as suas at...
# 174          8       2014  tremor da mao esq. desde há cerca de de 6 mese...
# 83           4       2015  dOENTE DE 65 ANOS, FUMADOR, EAM EM 2006, DPOC,...
# 1613         6       2013  Esta doente já foi observadas pela Dra. Raquel...
# 1119         3       2014  Utente sexo femenino, 62 anos. Tremor em repou...
# 856          8       2012  Doente de 31 anos, sem antecedentes pessoais r...
#
#      result                                                 80  \
# 1175      1  trémulo mais dos membros superiores - symptom_...
# 26        0  doente com 75 anos que sofreu symptom_identifi...
# 1441      1  justificação symptom_identified sindrome sympt...
# 528       1  homem de 51 anos com symptom_identified neurol...
# 910       1  utente de 32 anos, sem antec. clinicos relevan...
# 344       0                                 symptom_identified
# 372       0  doente do sexo masculino com 82 anos, analfabe...
# 954       1  homem de 76 anos avaliado em consulta por coli...
# 1605      1  doente de 79 anos, com quadro com pelo menos 1...
# 1137      1                                     sem informação
# 234       1  symptom_identified (excluindo n02 n89 r09) (n0...
# 72        1  reencaminho a utente porque o pedido realizado...
# 607       0  homem 88 anos, autonomo nas avd residente com ...
# 313       0  doente 22 anos, seguida na consulta externa of...
# 510       1  vida basal relativamente ativa para as suas at...
# 174       1  symptom_identified da mao esq. desde há cerca ...
# 83        0  doente de 65 anos, fumador, eam em 2006, dpoc,...
# 1613      1  esta doente já foi observadas pela dra. raquel...
# 1119      1  utente sexo femenino, 62 anos. symptom_identif...
# 856       1  doente de 31 anos, sem antecedentes pessoais r...
#
#       symptom_identified
# 1175                   4
# 26                     1
# 1441                  11
# 528                    5
# 910                    6
# 344                    1
# 372                    1
# 954                    3
# 1605                   2
# 1137                   0
# 234                    9
# 72                    10
# 607                    2
# 313                    6
# 510                    9
# 174                    3
# 83                     3
# 1613                   4
# 1119                   4
# 856                    1
#
# [20 rows x 34 columns]
